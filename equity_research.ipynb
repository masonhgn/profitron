# %%
from components.DataCollection import DataCollection
import pandas as pd
import numpy as np
import datetime
from statsmodels.tsa.stattools import coint, adfuller
import matplotlib.pyplot as plt
data = DataCollection()

# %% [markdown]
# Get all NYSE tickers, with closing price under $75

# %%
tickers = data.all_nyse_tickers()
tickers = [ticker for ticker in tickers if '$' not in ticker and '.' not in ticker]
filtered_tickers = data.filter_last_closing_price(75, tickers, 5)

print(len(tickers))
# Out:
# CBO: No data found for this date range, symbol may be delisted
# CBX: No data found, symbol may be delisted
# NTEST: No data found for this date range, symbol may be delisted
# 2439

# %%
#get 30 day stationarity of log returns
lookback = 30
stationary_tickers = []

for ticker in filtered_tickers:
    print('getting stationarity of ticker ' + ticker)
    prices = data.closing_prices(ticker, datetime.date.today() - datetime.timedelta(days=lookback),datetime.date.today())
    returns = data.log_returns(prices)

    try:
        reverting = adfuller(returns)
        pvalue = reverting[1]
        critical_value = reverting[4]['1%']
        test_statistic = reverting[0]

        if pvalue < 0.05 and test_statistic < critical_value:
            print('stationary')
            stationary_tickers.append(ticker)
    except:
        print('didnt work lol')
# Out:
# getting stationarity of ticker AA
# getting stationarity of ticker AACT
# stationary
# getting stationarity of ticker AAN
# getting stationarity of ticker AAP
# getting stationarity of ticker AAT
# getting stationarity of ticker AB
# getting stationarity of ticker ABCB
# getting stationarity of ticker ABEV
# getting stationarity of ticker ABM
# getting stationarity of ticker ABR
# getting stationarity of ticker AC
# getting stationarity of ticker ACCO
# getting stationarity of ticker ACEL
# getting stationarity of ticker ACHR
# getting stationarity of ticker ACI
# getting stationarity of ticker ACP
# getting stationarity of ticker ACR
# stationary
# getting stationarity of ticker ACRE
# stationary
# getting stationarity of ticker ACV
# getting stationarity of ticker ADCT
# getting stationarity of ticker ADM
# getting stationarity of ticker ADNT
# getting stationarity of ticker ADT
# stationary
# getting stationarity of ticker ADX
# getting stationarity of ticker AEFC
# getting stationarity of ticker AEG
# getting stationarity of ticker AEO
# getting stationarity of ticker AES
# getting stationarity of ticker AESI
# getting stationarity of ticker AEVA
# getting stationarity of ticker AFB
# getting stationarity of ticker AFGB
# stationary
# getting stationarity of ticker AFGC
# stationary
# getting stationarity of ticker AFGD
# stationary
# getting stationarity of ticker AFGE
# getting stationarity of ticker AG
# getting stationarity of ticker AGD
# getting stationarity of ticker AGI
# getting stationarity of ticker AGL
# getting stationarity of ticker AGR
# getting stationarity of ticker AGRO
# getting stationarity of ticker AGS
# stationary
# getting stationarity of ticker AHH
# getting stationarity of ticker AHR
# getting stationarity of ticker AHT
# stationary
# getting stationarity of ticker AI
# getting stationarity of ticker AIFD
# getting stationarity of ticker AIG
# stationary
# getting stationarity of ticker AIO
# getting stationarity of ticker AIR
# stationary
# getting stationarity of ticker AIV
# getting stationarity of ticker AIZN
# getting stationarity of ticker AJX
# stationary
# getting stationarity of ticker AKA
# stationary
# getting stationarity of ticker AKR
# getting stationarity of ticker AL
# stationary
# getting stationarity of ticker ALE
# getting stationarity of ticker ALEX
# getting stationarity of ticker ALIT
# getting stationarity of ticker ALK
# getting stationarity of ticker ALLY
# getting stationarity of ticker ALTG
# getting stationarity of ticker ALTM
# stationary
# getting stationarity of ticker ALUR
# stationary
# getting stationarity of ticker AM
# stationary
# getting stationarity of ticker AMBC
# getting stationarity of ticker AMBP
# getting stationarity of ticker AMC
# getting stationarity of ticker AMCR
# stationary
# getting stationarity of ticker AMH
# getting stationarity of ticker AMN
# stationary
# getting stationarity of ticker AMPS
# getting stationarity of ticker AMPX
# getting stationarity of ticker AMPY
# getting stationarity of ticker AMRC
# getting stationarity of ticker AMTB
# getting stationarity of ticker AMTD
# getting stationarity of ticker AMWL
# getting stationarity of ticker AMX
# stationary
# getting stationarity of ticker ANRO
# stationary
# getting stationarity of ticker ANVS
# getting stationarity of ticker AOD
# stationary
# getting stationarity of ticker AOMN
# getting stationarity of ticker AOMR
# stationary
# getting stationarity of ticker AORT
# getting stationarity of ticker AP
# getting stationarity of ticker APAM
# getting stationarity of ticker APG
# getting stationarity of ticker APH
# stationary
# getting stationarity of ticker APLE
# getting stationarity of ticker APOS
# getting stationarity of ticker APTV
# stationary
# getting stationarity of ticker AQN
# getting stationarity of ticker AQNB
# getting stationarity of ticker AR
# getting stationarity of ticker ARC
# stationary
# getting stationarity of ticker ARCO
# getting stationarity of ticker ARDC
# getting stationarity of ticker ARDT
# getting stationarity of ticker ARGD
# getting stationarity of ticker ARI
# getting stationarity of ticker ARIS
# getting stationarity of ticker ARL
# getting stationarity of ticker ARLO
# getting stationarity of ticker ARMK
# stationary
# getting stationarity of ticker AROC
# getting stationarity of ticker ARR
# stationary
# getting stationarity of ticker AS
# getting stationarity of ticker ASA
# getting stationarity of ticker ASAI
# getting stationarity of ticker ASAN
# getting stationarity of ticker ASB
# stationary
# getting stationarity of ticker ASBA
# getting stationarity of ticker ASC
# getting stationarity of ticker ASG
# getting stationarity of ticker ASGI
# stationary
# getting stationarity of ticker ASIX
# stationary
# getting stationarity of ticker ASPN
# getting stationarity of ticker ASX
# stationary
# getting stationarity of ticker ATEN
# getting stationarity of ticker ATGE
# getting stationarity of ticker ATHM
# getting stationarity of ticker ATHS
# getting stationarity of ticker ATI
# getting stationarity of ticker ATIP
# stationary
# getting stationarity of ticker ATMU
# getting stationarity of ticker ATS
# stationary
# getting stationarity of ticker ATUS
# stationary
# getting stationarity of ticker AU
# getting stationarity of ticker AUB
# stationary
# getting stationarity of ticker AUNA
# getting stationarity of ticker AVA
# stationary
# getting stationarity of ticker AVAL
# getting stationarity of ticker AVD
# stationary
# getting stationarity of ticker AVK
# getting stationarity of ticker AVNS
# stationary
# getting stationarity of ticker AVNT
# getting stationarity of ticker AVTR
# getting stationarity of ticker AWF
# stationary
# getting stationarity of ticker AWP
# getting stationarity of ticker AX
# stationary
# getting stationarity of ticker AXL
# getting stationarity of ticker AXR
# getting stationarity of ticker AXTA
# stationary
# getting stationarity of ticker AZEK
# getting stationarity of ticker AZUL
# getting stationarity of ticker B
# getting stationarity of ticker BAC
# stationary
# getting stationarity of ticker BAK
# getting stationarity of ticker BALL
# stationary
# getting stationarity of ticker BALY
# stationary
# getting stationarity of ticker BAM
# stationary
# getting stationarity of ticker BANC
# getting stationarity of ticker BARK
# getting stationarity of ticker BAX
# getting stationarity of ticker BB
# stationary
# getting stationarity of ticker BBAI
# stationary
# getting stationarity of ticker BBAR
# stationary
# getting stationarity of ticker BBD
# getting stationarity of ticker BBDC
# getting stationarity of ticker BBDO
# getting stationarity of ticker BBN
# stationary
# getting stationarity of ticker BBU
# getting stationarity of ticker BBUC
# getting stationarity of ticker BBVA
# stationary
# getting stationarity of ticker BBW
# stationary
# getting stationarity of ticker BBWI
# getting stationarity of ticker BCAT
# stationary
# getting stationarity of ticker BCE
# stationary
# getting stationarity of ticker BCH
# getting stationarity of ticker BCS
# getting stationarity of ticker BCSF
# stationary
# getting stationarity of ticker BCX
# stationary
# getting stationarity of ticker BDJ
# getting stationarity of ticker BDN
# getting stationarity of ticker BE
# stationary
# getting stationarity of ticker BEDU
# stationary
# getting stationarity of ticker BEKE
# stationary
# getting stationarity of ticker BEN
# stationary
# getting stationarity of ticker BEP
# getting stationarity of ticker BEPC
# getting stationarity of ticker BEPH
# getting stationarity of ticker BEPI
# stationary
# getting stationarity of ticker BEPJ
# stationary
# getting stationarity of ticker BERY
# getting stationarity of ticker BEST
# getting stationarity of ticker BFAC
# getting stationarity of ticker BFH
# getting stationarity of ticker BFK
# getting stationarity of ticker BFLY
# getting stationarity of ticker BFS
# getting stationarity of ticker BFZ
# getting stationarity of ticker BGB
# getting stationarity of ticker BGH
# getting stationarity of ticker BGR
# getting stationarity of ticker BGS
# getting stationarity of ticker BGSF
# stationary
# getting stationarity of ticker BGT
# stationary
# getting stationarity of ticker BGX
# stationary
# getting stationarity of ticker BGY
# stationary
# getting stationarity of ticker BHC
# getting stationarity of ticker BHE
# getting stationarity of ticker BHK
# getting stationarity of ticker BHLB
# stationary
# getting stationarity of ticker BHP
# getting stationarity of ticker BHR
# getting stationarity of ticker BHV
# getting stationarity of ticker BHVN
# getting stationarity of ticker BIGZ
# stationary
# getting stationarity of ticker BILL
# getting stationarity of ticker BIP
# getting stationarity of ticker BIPC
# stationary
# getting stationarity of ticker BIPH
# getting stationarity of ticker BIPI
# getting stationarity of ticker BIPJ
# getting stationarity of ticker BIRK
# getting stationarity of ticker BIT
# stationary
# getting stationarity of ticker BK
# getting stationarity of ticker BKD
# stationary
# getting stationarity of ticker BKE
# getting stationarity of ticker BKH
# getting stationarity of ticker BKKT
# getting stationarity of ticker BKN
# getting stationarity of ticker BKSY
# getting stationarity of ticker BKT
# getting stationarity of ticker BKU
# getting stationarity of ticker BLCO
# getting stationarity of ticker BLE
# getting stationarity of ticker BLND
# stationary
# getting stationarity of ticker BLW
# getting stationarity of ticker BLX
# getting stationarity of ticker BMA
# getting stationarity of ticker BME
# getting stationarity of ticker BMEZ
# stationary
# getting stationarity of ticker BMN
# stationary
# getting stationarity of ticker BMY
# getting stationarity of ticker BN
# getting stationarity of ticker BNED
# getting stationarity of ticker BNH
# getting stationarity of ticker BNJ
# getting stationarity of ticker BNL
# getting stationarity of ticker BNS
# getting stationarity of ticker BNT
# getting stationarity of ticker BNY
# getting stationarity of ticker BOC
# getting stationarity of ticker BODI
# stationary
# getting stationarity of ticker BOE
# getting stationarity of ticker BOH
# getting stationarity of ticker BORR
# stationary
# getting stationarity of ticker BOW
# getting stationarity of ticker BOWL
# getting stationarity of ticker BOX
# getting stationarity of ticker BP
# getting stationarity of ticker BPT
# getting stationarity of ticker BRBR
# stationary
# getting stationarity of ticker BRC
# stationary
# getting stationarity of ticker BRCC
# getting stationarity of ticker BRDG
# getting stationarity of ticker BRFS
# getting stationarity of ticker BROS
# getting stationarity of ticker BRSP
# getting stationarity of ticker BRT
# stationary
# getting stationarity of ticker BRW
# getting stationarity of ticker BRX
# stationary
# getting stationarity of ticker BSAC
# getting stationarity of ticker BSBR
# getting stationarity of ticker BSIG
# stationary
# getting stationarity of ticker BSL
# getting stationarity of ticker BSM
# getting stationarity of ticker BST
# getting stationarity of ticker BSTZ
# stationary
# getting stationarity of ticker BTA
# getting stationarity of ticker BTCM
# getting stationarity of ticker BTE
# getting stationarity of ticker BTI
# stationary
# getting stationarity of ticker BTO
# stationary
# getting stationarity of ticker BTT
# getting stationarity of ticker BTU
# getting stationarity of ticker BTZ
# getting stationarity of ticker BUD
# getting stationarity of ticker BUI
# getting stationarity of ticker BUR
# getting stationarity of ticker BUXX
# getting stationarity of ticker BV
# stationary
# getting stationarity of ticker BVN
# getting stationarity of ticker BW
# stationary
# getting stationarity of ticker BWA
# stationary
# getting stationarity of ticker BWG
# stationary
# getting stationarity of ticker BWLP
# getting stationarity of ticker BWMX
# getting stationarity of ticker BWNB
# stationary
# getting stationarity of ticker BWSN
# stationary
# getting stationarity of ticker BXMT
# getting stationarity of ticker BXMX
# stationary
# getting stationarity of ticker BXSL
# getting stationarity of ticker BY
# stationary
# getting stationarity of ticker BYD
# getting stationarity of ticker BYM
# getting stationarity of ticker BYON
# getting stationarity of ticker BZH
# getting stationarity of ticker C
# stationary
# getting stationarity of ticker CAAP
# getting stationarity of ticker CADE
# getting stationarity of ticker CAE
# getting stationarity of ticker CAF
# getting stationarity of ticker CAG
# stationary
# getting stationarity of ticker CAL
# stationary
# getting stationarity of ticker CALX
# getting stationarity of ticker CANG
# stationary
# getting stationarity of ticker CAPL
# stationary
# getting stationarity of ticker CARS
# getting stationarity of ticker CATO
# getting stationarity of ticker CBL
# stationary
# getting stationarity of ticker CBU
# stationary
# getting stationarity of ticker CBZ
# getting stationarity of ticker CC
# getting stationarity of ticker CCIA
# stationary
# getting stationarity of ticker CCIF
# getting stationarity of ticker CCJ
# stationary
# getting stationarity of ticker CCL
# getting stationarity of ticker CCM
# stationary
# getting stationarity of ticker CCO
# stationary
# getting stationarity of ticker CCRD
# getting stationarity of ticker CCU
# stationary
# getting stationarity of ticker CCZ
# didnt work lol
# getting stationarity of ticker CDE
# getting stationarity of ticker CDLR
# getting stationarity of ticker CDP
# getting stationarity of ticker CDRE
# getting stationarity of ticker CEE
# getting stationarity of ticker CEPU
# getting stationarity of ticker CFG
# stationary
# getting stationarity of ticker CGA
# getting stationarity of ticker CGAU
# getting stationarity of ticker CGV
# getting stationarity of ticker CHCT
# getting stationarity of ticker CHGG
# getting stationarity of ticker CHMI
# getting stationarity of ticker CHN
# stationary
# getting stationarity of ticker CHPT
# stationary
# getting stationarity of ticker CHT
# getting stationarity of ticker CHWY
# getting stationarity of ticker CIA
# stationary
# getting stationarity of ticker CIB
# getting stationarity of ticker CIEN
# getting stationarity of ticker CIF
# getting stationarity of ticker CIG
# stationary
# getting stationarity of ticker CII
# getting stationarity of ticker CIM
# getting stationarity of ticker CIMN
# getting stationarity of ticker CIMO
# getting stationarity of ticker CINT
# stationary
# getting stationarity of ticker CIO
# getting stationarity of ticker CION
# getting stationarity of ticker CIVI
# getting stationarity of ticker CLB
# getting stationarity of ticker CLBR
# getting stationarity of ticker CLCO
# getting stationarity of ticker CLDT
# stationary
# getting stationarity of ticker CLF
# getting stationarity of ticker CLPR
# getting stationarity of ticker CLS
# getting stationarity of ticker CLVT
# getting stationarity of ticker CLW
# getting stationarity of ticker CM
# getting stationarity of ticker CMA
# stationary
# getting stationarity of ticker CMBT
# getting stationarity of ticker CMC
# getting stationarity of ticker CMCM
# stationary
# getting stationarity of ticker CMG
# stationary
# getting stationarity of ticker CMP
# getting stationarity of ticker CMRE
# getting stationarity of ticker CMS
# stationary
# getting stationarity of ticker CMSA
# stationary
# getting stationarity of ticker CMSC
# getting stationarity of ticker CMSD
# getting stationarity of ticker CMTG
# getting stationarity of ticker CMU
# getting stationarity of ticker CNA
# getting stationarity of ticker CNF
# getting stationarity of ticker CNH
# getting stationarity of ticker CNK
# getting stationarity of ticker CNM
# stationary
# getting stationarity of ticker CNNE
# getting stationarity of ticker CNO
# getting stationarity of ticker CNP
# getting stationarity of ticker CNQ
# getting stationarity of ticker CNX
# getting stationarity of ticker CODI
# stationary
# getting stationarity of ticker COLD
# getting stationarity of ticker COMP
# stationary
# getting stationarity of ticker CON
# stationary
# getting stationarity of ticker COOK
# getting stationarity of ticker COTY
# getting stationarity of ticker COUR
# getting stationarity of ticker CPAC
# stationary
# getting stationarity of ticker CPF
# stationary
# getting stationarity of ticker CPNG
# stationary
# getting stationarity of ticker CPRI
# getting stationarity of ticker CPS
# getting stationarity of ticker CQP
# getting stationarity of ticker CRBG
# stationary
# getting stationarity of ticker CRC
# getting stationarity of ticker CRGY
# getting stationarity of ticker CRI
# getting stationarity of ticker CRK
# getting stationarity of ticker CRT
# stationary
# getting stationarity of ticker CSAN
# getting stationarity of ticker CSTM
# stationary
# getting stationarity of ticker CSV
# getting stationarity of ticker CTBB
# stationary
# getting stationarity of ticker CTDD
# getting stationarity of ticker CTEST
#
# 1 Failed download:
# - CTEST: Period 'max' is invalid, must be one of ['1d', '5d']
# didnt work lol
# getting stationarity of ticker CTLT
# getting stationarity of ticker CTO
# stationary
# getting stationarity of ticker CTOS
# getting stationarity of ticker CTRA
# getting stationarity of ticker CTRE
# stationary
# getting stationarity of ticker CTRI
# getting stationarity of ticker CTS
# getting stationarity of ticker CTV
# stationary
# getting stationarity of ticker CTVA
# getting stationarity of ticker CUBB
# stationary
# getting stationarity of ticker CUBE
# stationary
# getting stationarity of ticker CUBI
# stationary
# getting stationarity of ticker CUK
# getting stationarity of ticker CULP
# getting stationarity of ticker CURV
# getting stationarity of ticker CUZ
# getting stationarity of ticker CVE
# stationary
# getting stationarity of ticker CVEO
# getting stationarity of ticker CVI
# getting stationarity of ticker CVLG
# stationary
# getting stationarity of ticker CVS
# getting stationarity of ticker CWAN
# stationary
# getting stationarity of ticker CWEN
# getting stationarity of ticker CWH
# getting stationarity of ticker CWK
# getting stationarity of ticker CWT
# getting stationarity of ticker CX
# getting stationarity of ticker CXE
# getting stationarity of ticker CXH
# getting stationarity of ticker CXM
# getting stationarity of ticker CXT
# stationary
# getting stationarity of ticker CXW
# stationary
# getting stationarity of ticker CYD
# getting stationarity of ticker CYH
# stationary
# getting stationarity of ticker D
# stationary
# getting stationarity of ticker DAL
# getting stationarity of ticker DAN
# stationary
# getting stationarity of ticker DAO
# getting stationarity of ticker DAR
# getting stationarity of ticker DAVA
# getting stationarity of ticker DAY
# stationary
# getting stationarity of ticker DB
# getting stationarity of ticker DBD
# stationary
# getting stationarity of ticker DBI
# stationary
# getting stationarity of ticker DBL
# getting stationarity of ticker DBRG
# getting stationarity of ticker DCF
# getting stationarity of ticker DCI
# getting stationarity of ticker DCO
# getting stationarity of ticker DDD
# getting stationarity of ticker DDL
# getting stationarity of ticker DDT
# stationary
# getting stationarity of ticker DEA
# stationary
# getting stationarity of ticker DEC
# getting stationarity of ticker DEI
# getting stationarity of ticker DESP
# stationary
# getting stationarity of ticker DFH
# getting stationarity of ticker DFIN
# stationary
# getting stationarity of ticker DFP
# getting stationarity of ticker DHF
# getting stationarity of ticker DHT
# getting stationarity of ticker DHX
# stationary
# getting stationarity of ticker DIAX
# stationary
# getting stationarity of ticker DIN
# getting stationarity of ticker DINO
# getting stationarity of ticker DIVY
# getting stationarity of ticker DK
# getting stationarity of ticker DKL
# getting stationarity of ticker DLB
# getting stationarity of ticker DLNG
# getting stationarity of ticker DLX
# getting stationarity of ticker DLY
# getting stationarity of ticker DM
# stationary
# getting stationarity of ticker DMA
# getting stationarity of ticker DMB
# getting stationarity of ticker DMO
# stationary
# getting stationarity of ticker DNA
# getting stationarity of ticker DNB
# getting stationarity of ticker DNMR
# getting stationarity of ticker DNOW
# stationary
# getting stationarity of ticker DNP
# stationary
# getting stationarity of ticker DOC
# getting stationarity of ticker DOCN
# stationary
# getting stationarity of ticker DOCS
# stationary
# getting stationarity of ticker DOLE
# getting stationarity of ticker DOMA
# stationary
# getting stationarity of ticker DOUG
# getting stationarity of ticker DOW
# stationary
# getting stationarity of ticker DPG
# getting stationarity of ticker DQ
# stationary
# getting stationarity of ticker DRD
# getting stationarity of ticker DRH
# getting stationarity of ticker DRLL
# getting stationarity of ticker DSL
# stationary
# getting stationarity of ticker DSM
# getting stationarity of ticker DSMC
# getting stationarity of ticker DSTX
# getting stationarity of ticker DSU
# getting stationarity of ticker DSX
# getting stationarity of ticker DT
# stationary
# getting stationarity of ticker DTB
# getting stationarity of ticker DTC
# stationary
# getting stationarity of ticker DTF
# getting stationarity of ticker DTG
# getting stationarity of ticker DTW
# stationary
# getting stationarity of ticker DUKB
# stationary
# getting stationarity of ticker DV
# getting stationarity of ticker DVN
# getting stationarity of ticker DX
# getting stationarity of ticker DXC
# getting stationarity of ticker DXYZ
# stationary
# getting stationarity of ticker E
# getting stationarity of ticker EAF
# getting stationarity of ticker EAI
#
# 1 Failed download:
# - EAI: No data found for this date range, symbol may be delisted
# didnt work lol
# getting stationarity of ticker EARN
# getting stationarity of ticker EAT
# stationary
# getting stationarity of ticker EB
# getting stationarity of ticker EBF
# getting stationarity of ticker EBR
# getting stationarity of ticker EBS
# getting stationarity of ticker EC
# getting stationarity of ticker ECAT
# getting stationarity of ticker ECC
# getting stationarity of ticker ECCC
# getting stationarity of ticker ECCF
# getting stationarity of ticker ECCV
# stationary
# getting stationarity of ticker ECCW
# getting stationarity of ticker ECCX
# getting stationarity of ticker ECO
# getting stationarity of ticker ECVT
# getting stationarity of ticker EDD
# getting stationarity of ticker EDF
# stationary
# getting stationarity of ticker EDN
# getting stationarity of ticker EDR
# getting stationarity of ticker EDU
# getting stationarity of ticker EE
# getting stationarity of ticker EEA
# stationary
# getting stationarity of ticker EEX
# stationary
# getting stationarity of ticker EFC
# stationary
# getting stationarity of ticker EFR
# getting stationarity of ticker EFT
# stationary
# getting stationarity of ticker EFXT
# stationary
# getting stationarity of ticker EGF
# getting stationarity of ticker EGO
# getting stationarity of ticker EGY
# getting stationarity of ticker EHAB
# getting stationarity of ticker EHI
# getting stationarity of ticker EIC
# getting stationarity of ticker EICA
# getting stationarity of ticker EICB
# getting stationarity of ticker EICC
# getting stationarity of ticker EIG
# getting stationarity of ticker ELAN
# getting stationarity of ticker ELC
# stationary
# getting stationarity of ticker ELME
# getting stationarity of ticker ELP
# getting stationarity of ticker ELPC
# stationary
# getting stationarity of ticker EMD
# stationary
# getting stationarity of ticker EMF
# getting stationarity of ticker EMO
# getting stationarity of ticker EMP
#
# 1 Failed download:
# - EMP: No data found for this date range, symbol may be delisted
# didnt work lol
# getting stationarity of ticker ENB
# getting stationarity of ticker ENFN
# getting stationarity of ticker ENIC
# getting stationarity of ticker ENJ
# getting stationarity of ticker ENLC
# stationary
# getting stationarity of ticker ENO
# stationary
# getting stationarity of ticker ENOV
# getting stationarity of ticker ENR
# stationary
# getting stationarity of ticker ENV
# stationary
# getting stationarity of ticker ENZ
# stationary
# getting stationarity of ticker EOD
# getting stationarity of ticker EOI
# getting stationarity of ticker EOS
# getting stationarity of ticker EOT
# stationary
# getting stationarity of ticker EPAC
# getting stationarity of ticker EPC
# getting stationarity of ticker EPD
# getting stationarity of ticker EPR
# getting stationarity of ticker EPRT
# getting stationarity of ticker EQBK
# stationary
# getting stationarity of ticker EQC
# getting stationarity of ticker EQH
# stationary
# getting stationarity of ticker EQNR
# getting stationarity of ticker EQS
# getting stationarity of ticker EQT
# getting stationarity of ticker ERJ
# stationary
# getting stationarity of ticker ERO
# getting stationarity of ticker ES
# stationary
# getting stationarity of ticker ESI
# stationary
# getting stationarity of ticker ESNT
# getting stationarity of ticker ESRT
# stationary
# getting stationarity of ticker ET
# getting stationarity of ticker ETB
# stationary
# getting stationarity of ticker ETD
# stationary
# getting stationarity of ticker ETG
# getting stationarity of ticker ETJ
# getting stationarity of ticker ETO
# getting stationarity of ticker ETV
# getting stationarity of ticker ETW
# getting stationarity of ticker ETWO
# stationary
# getting stationarity of ticker ETX
# getting stationarity of ticker ETY
# stationary
# getting stationarity of ticker EVA
# stationary
# getting stationarity of ticker EVC
# getting stationarity of ticker EVEX
# getting stationarity of ticker EVF
# stationary
# getting stationarity of ticker EVG
# getting stationarity of ticker EVH
# getting stationarity of ticker EVN
# getting stationarity of ticker EVRI
# getting stationarity of ticker EVT
# stationary
# getting stationarity of ticker EVTC
# getting stationarity of ticker EVTL
# getting stationarity of ticker EVTR
# stationary
# getting stationarity of ticker EW
# getting stationarity of ticker EXG
# getting stationarity of ticker EXK
# getting stationarity of ticker EXTO
# getting stationarity of ticker F
# stationary
# getting stationarity of ticker FAF
# getting stationarity of ticker FAM
# stationary
# getting stationarity of ticker FBK
# getting stationarity of ticker FBMS
# getting stationarity of ticker FBP
# stationary
# getting stationarity of ticker FBRT
# getting stationarity of ticker FC
# stationary
# getting stationarity of ticker FCF
# getting stationarity of ticker FCPT
# getting stationarity of ticker FCRX
# getting stationarity of ticker FCT
# stationary
# getting stationarity of ticker FCX
# getting stationarity of ticker FDP
# getting stationarity of ticker FE
# getting stationarity of ticker FEDU
# getting stationarity of ticker FENG
# getting stationarity of ticker FET
# getting stationarity of ticker FF
# stationary
# getting stationarity of ticker FFA
# getting stationarity of ticker FFC
# getting stationarity of ticker FFWM
# stationary
# getting stationarity of ticker FG
# getting stationarity of ticker FGB
# getting stationarity of ticker FGN
# getting stationarity of ticker FHI
# getting stationarity of ticker FHN
# stationary
# getting stationarity of ticker FIGS
# getting stationarity of ticker FIHL
# getting stationarity of ticker FINS
# stationary
# getting stationarity of ticker FINV
# stationary
# getting stationarity of ticker FL
# stationary
# getting stationarity of ticker FLC
# getting stationarity of ticker FLNG
# getting stationarity of ticker FLO
# getting stationarity of ticker FLR
# stationary
# getting stationarity of ticker FLS
# stationary
# getting stationarity of ticker FLXR
# stationary
# getting stationarity of ticker FMC
# getting stationarity of ticker FMN
# stationary
# getting stationarity of ticker FMS
# stationary
# getting stationarity of ticker FMY
# getting stationarity of ticker FNA
# getting stationarity of ticker FNB
# getting stationarity of ticker FNF
# stationary
# getting stationarity of ticker FOA
# stationary
# getting stationarity of ticker FOF
# stationary
# getting stationarity of ticker FOR
# getting stationarity of ticker FPF
# getting stationarity of ticker FPH
# stationary
# getting stationarity of ticker FPI
# getting stationarity of ticker FR
# getting stationarity of ticker FRA
# getting stationarity of ticker FREY
# getting stationarity of ticker FRGE
# getting stationarity of ticker FRO
# getting stationarity of ticker FSCO
# getting stationarity of ticker FSK
# getting stationarity of ticker FSLY
# getting stationarity of ticker FSM
# getting stationarity of ticker FT
# getting stationarity of ticker FTHY
# stationary
# getting stationarity of ticker FTI
# getting stationarity of ticker FTK
# getting stationarity of ticker FTS
# getting stationarity of ticker FTV
# getting stationarity of ticker FTWO
# getting stationarity of ticker FUBO
# getting stationarity of ticker FUN
# stationary
# getting stationarity of ticker FVRR
# getting stationarity of ticker FXED
# getting stationarity of ticker G
# stationary
# getting stationarity of ticker GAB
# getting stationarity of ticker GAM
# getting stationarity of ticker GAP
# getting stationarity of ticker GATO
# getting stationarity of ticker GB
# getting stationarity of ticker GBAB
# getting stationarity of ticker GBCI
# stationary
# getting stationarity of ticker GBLI
# getting stationarity of ticker GBTG
# getting stationarity of ticker GBX
# getting stationarity of ticker GCI
# getting stationarity of ticker GCO
# stationary
# getting stationarity of ticker GCTS
# getting stationarity of ticker GCV
# getting stationarity of ticker GDIV
# stationary
# getting stationarity of ticker GDL
# getting stationarity of ticker GDO
# getting stationarity of ticker GDOT
# getting stationarity of ticker GDV
# getting stationarity of ticker GEF
# stationary
# getting stationarity of ticker GEL
# getting stationarity of ticker GENI
# getting stationarity of ticker GEO
# getting stationarity of ticker GES
# getting stationarity of ticker GETY
# getting stationarity of ticker GF
# getting stationarity of ticker GFF
# getting stationarity of ticker GFI
# getting stationarity of ticker GFL
# stationary
# getting stationarity of ticker GFR
# getting stationarity of ticker GGB
# stationary
# getting stationarity of ticker GGT
# getting stationarity of ticker GGZ
# getting stationarity of ticker GHG
# stationary
# getting stationarity of ticker GHI
# getting stationarity of ticker GHLD
# getting stationarity of ticker GHM
# getting stationarity of ticker GHY
# stationary
# getting stationarity of ticker GIC
# stationary
# getting stationarity of ticker GIL
# getting stationarity of ticker GIS
# stationary
# getting stationarity of ticker GJH
# getting stationarity of ticker GJO
# stationary
# getting stationarity of ticker GJP
# stationary
# getting stationarity of ticker GJR
# getting stationarity of ticker GJS
# stationary
# getting stationarity of ticker GJT
# getting stationarity of ticker GLP
# getting stationarity of ticker GLT
# getting stationarity of ticker GLW
# stationary
# getting stationarity of ticker GM
# stationary
# getting stationarity of ticker GME
# getting stationarity of ticker GMED
# getting stationarity of ticker GMRE
# getting stationarity of ticker GNE
# stationary
# getting stationarity of ticker GNK
# getting stationarity of ticker GNL
# stationary
# getting stationarity of ticker GNT
# stationary
# getting stationarity of ticker GNTY
# stationary
# getting stationarity of ticker GNW
# getting stationarity of ticker GOF
# getting stationarity of ticker GOLD
# getting stationarity of ticker GOLF
# stationary
# getting stationarity of ticker GOOS
# getting stationarity of ticker GOTU
# stationary
# getting stationarity of ticker GPJA
# getting stationarity of ticker GPK
# getting stationarity of ticker GPMT
# getting stationarity of ticker GPRK
# getting stationarity of ticker GRC
# getting stationarity of ticker GRND
# getting stationarity of ticker GRNT
# getting stationarity of ticker GROV
# stationary
# getting stationarity of ticker GRW
# stationary
# getting stationarity of ticker GRX
# stationary
# getting stationarity of ticker GSBD
# getting stationarity of ticker GSK
# getting stationarity of ticker GSL
# stationary
# getting stationarity of ticker GTES
# getting stationarity of ticker GTN
# getting stationarity of ticker GTY
# getting stationarity of ticker GUG
# stationary
# getting stationarity of ticker GUT
# stationary
# getting stationarity of ticker GWH
# getting stationarity of ticker GXO
# getting stationarity of ticker GYLD
# stationary
# getting stationarity of ticker HAFN
# getting stationarity of ticker HAL
# getting stationarity of ticker HASI
# getting stationarity of ticker HAYW
# stationary
# getting stationarity of ticker HBB
# getting stationarity of ticker HBI
# getting stationarity of ticker HBM
# stationary
# getting stationarity of ticker HCC
# getting stationarity of ticker HCXY
# stationary
# getting stationarity of ticker HDB
# getting stationarity of ticker HE
# stationary
# getting stationarity of ticker HEQ
# stationary
# getting stationarity of ticker HESM
# stationary
# getting stationarity of ticker HFRO
# stationary
# getting stationarity of ticker HG
# getting stationarity of ticker HGER
# getting stationarity of ticker HGLB
# getting stationarity of ticker HGTY
# getting stationarity of ticker HGV
# getting stationarity of ticker HI
# getting stationarity of ticker HIE
# stationary
# getting stationarity of ticker HIMS
# getting stationarity of ticker HIO
# stationary
# getting stationarity of ticker HIPO
# getting stationarity of ticker HIW
# stationary
# getting stationarity of ticker HIX
# getting stationarity of ticker HKD
# stationary
# getting stationarity of ticker HL
# getting stationarity of ticker HLF
# stationary
# getting stationarity of ticker HLIO
# stationary
# getting stationarity of ticker HLLY
# getting stationarity of ticker HLN
# stationary
# getting stationarity of ticker HLX
# getting stationarity of ticker HMC
# getting stationarity of ticker HMN
# getting stationarity of ticker HMY
# getting stationarity of ticker HNI
# getting stationarity of ticker HOG
# getting stationarity of ticker HOMB
# stationary
# getting stationarity of ticker HOUS
# getting stationarity of ticker HP
# getting stationarity of ticker HPE
# getting stationarity of ticker HPF
# getting stationarity of ticker HPI
# stationary
# getting stationarity of ticker HPP
# stationary
# getting stationarity of ticker HPQ
# getting stationarity of ticker HPS
# stationary
# getting stationarity of ticker HQH
# getting stationarity of ticker HQL
# getting stationarity of ticker HR
# getting stationarity of ticker HRB
# getting stationarity of ticker HRL
# stationary
# getting stationarity of ticker HRTG
# getting stationarity of ticker HSBC
# stationary
# getting stationarity of ticker HSHP
# getting stationarity of ticker HTD
# getting stationarity of ticker HTFB
# stationary
# getting stationarity of ticker HTFC
# getting stationarity of ticker HTGC
# getting stationarity of ticker HTH
# getting stationarity of ticker HUN
# stationary
# getting stationarity of ticker HUYA
# getting stationarity of ticker HVT
# getting stationarity of ticker HXL
# stationary
# getting stationarity of ticker HY
# stationary
# getting stationarity of ticker HYAC
# getting stationarity of ticker HYB
# getting stationarity of ticker HYI
# getting stationarity of ticker HYLN
# getting stationarity of ticker HYT
# stationary
# getting stationarity of ticker HZO
# getting stationarity of ticker IAE
# getting stationarity of ticker IAG
# stationary
# getting stationarity of ticker IBN
# stationary
# getting stationarity of ticker IBTA
# stationary
# getting stationarity of ticker ICL
# getting stationarity of ticker IDE
# getting stationarity of ticker IDT
# getting stationarity of ticker IFN
# stationary
# getting stationarity of ticker IFS
# stationary
# getting stationarity of ticker IGA
# getting stationarity of ticker IGD
# getting stationarity of ticker IGI
# getting stationarity of ticker IGR
# stationary
# getting stationarity of ticker IGT
# getting stationarity of ticker IH
# getting stationarity of ticker IHD
# getting stationarity of ticker IHS
# getting stationarity of ticker IHTA
# stationary
# getting stationarity of ticker IIF
# getting stationarity of ticker IIIN
# getting stationarity of ticker IIM
# getting stationarity of ticker IMAX
# getting stationarity of ticker INFA
# getting stationarity of ticker INFY
# getting stationarity of ticker ING
# stationary
# getting stationarity of ticker INN
# getting stationarity of ticker INSI
# getting stationarity of ticker INST
# getting stationarity of ticker INSW
# getting stationarity of ticker INVH
# getting stationarity of ticker INVX
# stationary
# getting stationarity of ticker IONQ
# getting stationarity of ticker IOT
# getting stationarity of ticker IP
# getting stationarity of ticker IPB
# stationary
# getting stationarity of ticker IPG
# getting stationarity of ticker IPI
# stationary
# getting stationarity of ticker IQI
# getting stationarity of ticker IRS
# getting stationarity of ticker IRT
# getting stationarity of ticker ISD
# getting stationarity of ticker ITUB
# stationary
# getting stationarity of ticker IVR
# stationary
# getting stationarity of ticker IVT
# getting stationarity of ticker IVZ
# stationary
# getting stationarity of ticker JBGS
# getting stationarity of ticker JBI
# getting stationarity of ticker JBK
# stationary
# getting stationarity of ticker JBND
# getting stationarity of ticker JCE
# getting stationarity of ticker JCI
# stationary
# getting stationarity of ticker JEF
# getting stationarity of ticker JELD
# getting stationarity of ticker JEQ
# stationary
# getting stationarity of ticker JFR
# getting stationarity of ticker JGH
# getting stationarity of ticker JHG
# getting stationarity of ticker JHI
# stationary
# getting stationarity of ticker JHS
# getting stationarity of ticker JHX
# getting stationarity of ticker JILL
# stationary
# getting stationarity of ticker JKS
# stationary
# getting stationarity of ticker JLS
# stationary
# getting stationarity of ticker JMIA
# stationary
# getting stationarity of ticker JMM
# getting stationarity of ticker JNPR
# getting stationarity of ticker JOBY
# getting stationarity of ticker JOE
# stationary
# getting stationarity of ticker JOF
# getting stationarity of ticker JPC
# getting stationarity of ticker JPI
# stationary
# getting stationarity of ticker JQC
# getting stationarity of ticker JRI
# stationary
# getting stationarity of ticker JRS
# getting stationarity of ticker JWN
# stationary
# getting stationarity of ticker KAR
# getting stationarity of ticker KB
# getting stationarity of ticker KBDC
# getting stationarity of ticker KBR
# getting stationarity of ticker KD
# stationary
# getting stationarity of ticker KEN
# getting stationarity of ticker KEP
# getting stationarity of ticker KEY
# stationary
# getting stationarity of ticker KF
# getting stationarity of ticker KFRC
# stationary
# getting stationarity of ticker KFS
# stationary
# getting stationarity of ticker KFY
# getting stationarity of ticker KGC
# getting stationarity of ticker KGS
# stationary
# getting stationarity of ticker KIM
# stationary
# getting stationarity of ticker KIND
# stationary
# getting stationarity of ticker KIO
# stationary
# getting stationarity of ticker KKRS
# getting stationarity of ticker KLG
# stationary
# getting stationarity of ticker KMI
# getting stationarity of ticker KMPB
# getting stationarity of ticker KMPR
# stationary
# getting stationarity of ticker KMT
# getting stationarity of ticker KN
# getting stationarity of ticker KNOP
# getting stationarity of ticker KNTK
# getting stationarity of ticker KNX
# stationary
# getting stationarity of ticker KO
# getting stationarity of ticker KODK
# getting stationarity of ticker KOP
# getting stationarity of ticker KORE
# stationary
# getting stationarity of ticker KOS
# getting stationarity of ticker KR
# getting stationarity of ticker KRC
# getting stationarity of ticker KREF
# stationary
# getting stationarity of ticker KRG
# getting stationarity of ticker KRO
# stationary
# getting stationarity of ticker KRP
# getting stationarity of ticker KSM
# getting stationarity of ticker KSS
# stationary
# getting stationarity of ticker KT
# stationary
# getting stationarity of ticker KTB
# getting stationarity of ticker KTF
# getting stationarity of ticker KTH
# getting stationarity of ticker KTN
# stationary
# getting stationarity of ticker KUKE
# getting stationarity of ticker KVUE
# getting stationarity of ticker KVYO
# getting stationarity of ticker KW
# getting stationarity of ticker KYN
# stationary
# getting stationarity of ticker LAAC
# getting stationarity of ticker LAC
# getting stationarity of ticker LADR
# stationary
# getting stationarity of ticker LANV
# stationary
# getting stationarity of ticker LAW
# getting stationarity of ticker LAZ
# getting stationarity of ticker LB
# getting stationarity of ticker LBRT
# getting stationarity of ticker LC
# stationary
# getting stationarity of ticker LDI
# stationary
# getting stationarity of ticker LDP
# getting stationarity of ticker LEG
# stationary
# getting stationarity of ticker LEO
# getting stationarity of ticker LEV
# stationary
# getting stationarity of ticker LEVI
# stationary
# getting stationarity of ticker LFT
# getting stationarity of ticker LGI
# getting stationarity of ticker LICY
# getting stationarity of ticker LITB
# stationary
# getting stationarity of ticker LLAP
# getting stationarity of ticker LMND
# getting stationarity of ticker LNC
# getting stationarity of ticker LND
# getting stationarity of ticker LOB
# getting stationarity of ticker LOCL
# stationary
# getting stationarity of ticker LOMA
# getting stationarity of ticker LPG
# getting stationarity of ticker LPL
# getting stationarity of ticker LSPD
# stationary
# getting stationarity of ticker LTC
# stationary
# getting stationarity of ticker LTH
# getting stationarity of ticker LTM
# getting stationarity of ticker LU
# getting stationarity of ticker LUMN
# stationary
# getting stationarity of ticker LUV
# getting stationarity of ticker LVS
# getting stationarity of ticker LVWR
# getting stationarity of ticker LW
# getting stationarity of ticker LXFR
# getting stationarity of ticker LXP
# getting stationarity of ticker LXU
# stationary
# getting stationarity of ticker LYG
# stationary
# getting stationarity of ticker LZB
# getting stationarity of ticker LZM
# getting stationarity of ticker M
# getting stationarity of ticker MAC
# stationary
# getting stationarity of ticker MAIN
# getting stationarity of ticker MAN
# getting stationarity of ticker MANU
# stationary
# getting stationarity of ticker MATV
# getting stationarity of ticker MAV
# getting stationarity of ticker MAX
# stationary
# getting stationarity of ticker MBC
# getting stationarity of ticker MBI
# getting stationarity of ticker MC
# getting stationarity of ticker MCB
# getting stationarity of ticker MCI
# getting stationarity of ticker MCN
# getting stationarity of ticker MCR
# getting stationarity of ticker MCS
# stationary
# getting stationarity of ticker MCW
# getting stationarity of ticker MCY
# getting stationarity of ticker MD
# getting stationarity of ticker MDST
# stationary
# getting stationarity of ticker MDU
# stationary
# getting stationarity of ticker MDV
# stationary
# getting stationarity of ticker MEC
# getting stationarity of ticker MED
# stationary
# getting stationarity of ticker MEG
# stationary
# getting stationarity of ticker MEGI
# stationary
# getting stationarity of ticker MEI
# stationary
# getting stationarity of ticker MFA
# getting stationarity of ticker MFAN
# stationary
# getting stationarity of ticker MFAO
# stationary
# getting stationarity of ticker MFC
# stationary
# getting stationarity of ticker MFD
# stationary
# getting stationarity of ticker MFG
# getting stationarity of ticker MFM
# getting stationarity of ticker MG
# stationary
# getting stationarity of ticker MGA
# getting stationarity of ticker MGF
# getting stationarity of ticker MGM
# stationary
# getting stationarity of ticker MGR
# getting stationarity of ticker MGRB
# getting stationarity of ticker MGRD
# getting stationarity of ticker MGRE
# stationary
# getting stationarity of ticker MGY
# getting stationarity of ticker MHD
# getting stationarity of ticker MHF
# stationary
# getting stationarity of ticker MHI
# getting stationarity of ticker MHLA
# getting stationarity of ticker MHN
# getting stationarity of ticker MHNC
# stationary
# getting stationarity of ticker MIN
# stationary
# getting stationarity of ticker MIO
# getting stationarity of ticker MIR
# stationary
# getting stationarity of ticker MITN
# stationary
# getting stationarity of ticker MITP
# getting stationarity of ticker MITT
# getting stationarity of ticker MIY
# getting stationarity of ticker MKFG
# stationary
# getting stationarity of ticker ML
# getting stationarity of ticker MLI
# stationary
# getting stationarity of ticker MLNK
# stationary
# getting stationarity of ticker MLP
# stationary
# getting stationarity of ticker MLR
# getting stationarity of ticker MMD
# stationary
# getting stationarity of ticker MMI
# getting stationarity of ticker MMT
# stationary
# getting stationarity of ticker MMU
# getting stationarity of ticker MNR
# getting stationarity of ticker MNSO
# getting stationarity of ticker MNTN
# getting stationarity of ticker MO
# getting stationarity of ticker MODG
# stationary
# getting stationarity of ticker MOGU
# getting stationarity of ticker MOS
# getting stationarity of ticker MOV
# getting stationarity of ticker MP
# getting stationarity of ticker MPA
# getting stationarity of ticker MPLN
# getting stationarity of ticker MPLX
# stationary
# getting stationarity of ticker MPV
# stationary
# getting stationarity of ticker MPW
# getting stationarity of ticker MPX
# stationary
# getting stationarity of ticker MQT
# getting stationarity of ticker MQY
# getting stationarity of ticker MRC
# getting stationarity of ticker MRO
# getting stationarity of ticker MSB
# getting stationarity of ticker MSC
# getting stationarity of ticker MSD
# getting stationarity of ticker MSDL
# getting stationarity of ticker MSGE
# stationary
# getting stationarity of ticker MT
# stationary
# getting stationarity of ticker MTAL
# stationary
# getting stationarity of ticker MTDR
# getting stationarity of ticker MTG
# getting stationarity of ticker MTR
# getting stationarity of ticker MTUS
# stationary
# getting stationarity of ticker MTW
# stationary
# getting stationarity of ticker MTX
# stationary
# getting stationarity of ticker MUA
# stationary
# getting stationarity of ticker MUC
# getting stationarity of ticker MUE
# getting stationarity of ticker MUFG
# getting stationarity of ticker MUI
# getting stationarity of ticker MUJ
# stationary
# getting stationarity of ticker MUR
# getting stationarity of ticker MUX
# getting stationarity of ticker MVF
# stationary
# getting stationarity of ticker MVO
# getting stationarity of ticker MVT
# getting stationarity of ticker MWA
# getting stationarity of ticker MX
# getting stationarity of ticker MXE
# getting stationarity of ticker MXF
# getting stationarity of ticker MYD
# getting stationarity of ticker MYE
# getting stationarity of ticker MYI
# getting stationarity of ticker MYN
# stationary
# getting stationarity of ticker MYTE
# stationary
# getting stationarity of ticker NABL
# getting stationarity of ticker NAC
# getting stationarity of ticker NAD
# stationary
# getting stationarity of ticker NAN
# getting stationarity of ticker NAPA
# stationary
# getting stationarity of ticker NAT
# stationary
# getting stationarity of ticker NATL
# getting stationarity of ticker NAZ
# getting stationarity of ticker NBB
# stationary
# getting stationarity of ticker NBHC
# getting stationarity of ticker NBR
# stationary
# getting stationarity of ticker NBXG
# getting stationarity of ticker NC
# getting stationarity of ticker NCA
# getting stationarity of ticker NCDL
# stationary
# getting stationarity of ticker NCLH
# stationary
# getting stationarity of ticker NCV
# getting stationarity of ticker NCZ
# getting stationarity of ticker NDMO
# getting stationarity of ticker NDP
# stationary
# getting stationarity of ticker NE
# getting stationarity of ticker NEA
# stationary
# getting stationarity of ticker NEM
# stationary
# getting stationarity of ticker NEP
# stationary
# getting stationarity of ticker NETZ
# stationary
# getting stationarity of ticker NEUE
# stationary
# getting stationarity of ticker NEXA
# getting stationarity of ticker NFG
# stationary
# getting stationarity of ticker NFJ
# getting stationarity of ticker NGG
# stationary
# getting stationarity of ticker NGL
# stationary
# getting stationarity of ticker NGS
# getting stationarity of ticker NGVC
# getting stationarity of ticker NGVT
# getting stationarity of ticker NI
# getting stationarity of ticker NIE
# getting stationarity of ticker NIM
# getting stationarity of ticker NINE
# stationary
# getting stationarity of ticker NIO
# getting stationarity of ticker NJR
# getting stationarity of ticker NKX
# stationary
# getting stationarity of ticker NL
# stationary
# getting stationarity of ticker NLOP
# stationary
# getting stationarity of ticker NLY
# getting stationarity of ticker NMAI
# getting stationarity of ticker NMCO
# getting stationarity of ticker NMG
# getting stationarity of ticker NMI
# getting stationarity of ticker NMM
# stationary
# getting stationarity of ticker NMR
# stationary
# getting stationarity of ticker NMS
# stationary
# getting stationarity of ticker NMT
# getting stationarity of ticker NMZ
# getting stationarity of ticker NNN
# getting stationarity of ticker NNY
# getting stationarity of ticker NOA
# getting stationarity of ticker NOAH
# stationary
# getting stationarity of ticker NOG
# getting stationarity of ticker NOK
# stationary
# getting stationarity of ticker NOM
# getting stationarity of ticker NOMD
# getting stationarity of ticker NOTE
# getting stationarity of ticker NOV
# getting stationarity of ticker NOVA
# getting stationarity of ticker NPCT
# getting stationarity of ticker NPFD
# getting stationarity of ticker NPV
# getting stationarity of ticker NPWR
# stationary
# getting stationarity of ticker NQP
# getting stationarity of ticker NR
# getting stationarity of ticker NRDY
# stationary
# getting stationarity of ticker NREF
# stationary
# getting stationarity of ticker NRGV
# getting stationarity of ticker NRK
# getting stationarity of ticker NRT
# stationary
# getting stationarity of ticker NRUC
# stationary
# getting stationarity of ticker NSA
# stationary
# ...
# getting stationarity of ticker SAJ
# getting stationarity of ticker SAN
# stationary
# getting stationarity of ticker SAND
# stationary
# getting stationarity of ticker SAR
# getting stationarity of ticker SAT
# stationary
# getting stationarity of ticker SAVE
# getting stationarity of ticker SAY
# getting stationarity of ticker SAZ
# getting stationarity of ticker SB
# getting stationarity of ticker SBBA
# getting stationarity of ticker SBH
# getting stationarity of ticker SBI
# getting stationarity of ticker SBR
# getting stationarity of ticker SBS
# getting stationarity of ticker SBSW
# getting stationarity of ticker SBXC
# getting stationarity of ticker SCD
# getting stationarity of ticker SCHW
# getting stationarity of ticker SCL
# getting stationarity of ticker SCM
# stationary
# getting stationarity of ticker SCS
# getting stationarity of ticker SD
# stationary
# getting stationarity of ticker SDHC
# getting stationarity of ticker SDHY
# getting stationarity of ticker SDRL
# getting stationarity of ticker SEDA
# stationary
# getting stationarity of ticker SEE
# getting stationarity of ticker SEI
# getting stationarity of ticker SEM
# stationary
# getting stationarity of ticker SEMR
# stationary
# getting stationarity of ticker SES
# stationary
# getting stationarity of ticker SFB
#
# 1 Failed download:
# - SFB: Period 'max' is invalid, must be one of ['1d', '5d']
# didnt work lol
# getting stationarity of ticker SFL
# getting stationarity of ticker SG
# getting stationarity of ticker SGHC
# stationary
# getting stationarity of ticker SGU
# getting stationarity of ticker SHCO
# stationary
# getting stationarity of ticker SHEL
# getting stationarity of ticker SHG
# getting stationarity of ticker SHO
# getting stationarity of ticker SHOC
# getting stationarity of ticker SHOP
# getting stationarity of ticker SID
# stationary
# getting stationarity of ticker SII
# stationary
# getting stationarity of ticker SILA
# stationary
# getting stationarity of ticker SITC
# getting stationarity of ticker SJT
# stationary
# getting stationarity of ticker SJW
# getting stationarity of ticker SKE
# getting stationarity of ticker SKIL
# stationary
# getting stationarity of ticker SKLZ
# getting stationarity of ticker SKM
# getting stationarity of ticker SKT
# stationary
# getting stationarity of ticker SKX
# getting stationarity of ticker SLB
# getting stationarity of ticker SLF
# stationary
# getting stationarity of ticker SLG
# getting stationarity of ticker SLGN
# getting stationarity of ticker SLQT
# getting stationarity of ticker SM
# getting stationarity of ticker SMAR
# getting stationarity of ticker SMBK
# stationary
# getting stationarity of ticker SMC
# getting stationarity of ticker SMFG
# getting stationarity of ticker SMG
# getting stationarity of ticker SMHI
# getting stationarity of ticker SMP
# getting stationarity of ticker SMR
# getting stationarity of ticker SMRT
# getting stationarity of ticker SMWB
# getting stationarity of ticker SNAP
# getting stationarity of ticker SNDA
# getting stationarity of ticker SNDR
# stationary
# getting stationarity of ticker SNN
# getting stationarity of ticker SNV
# stationary
# getting stationarity of ticker SOC
# stationary
# getting stationarity of ticker SOJC
# getting stationarity of ticker SOJD
# stationary
# getting stationarity of ticker SOJE
# getting stationarity of ticker SOL
# getting stationarity of ticker SOLV
# stationary
# getting stationarity of ticker SON
# getting stationarity of ticker SOR
# stationary
# getting stationarity of ticker SOS
# getting stationarity of ticker SPCE
# getting stationarity of ticker SPE
# getting stationarity of ticker SPH
# stationary
# getting stationarity of ticker SPHR
# getting stationarity of ticker SPIR
# stationary
# getting stationarity of ticker SPLP
# getting stationarity of ticker SPMC
# stationary
# getting stationarity of ticker SPNT
# getting stationarity of ticker SPR
# getting stationarity of ticker SPRU
# getting stationarity of ticker SPXX
# getting stationarity of ticker SQ
# getting stationarity of ticker SQM
# stationary
# getting stationarity of ticker SQNS
# getting stationarity of ticker SQSP
# getting stationarity of ticker SR
# getting stationarity of ticker SREA
# getting stationarity of ticker SRFM
# getting stationarity of ticker SRG
# getting stationarity of ticker SRI
# getting stationarity of ticker SRL
# stationary
# getting stationarity of ticker SRV
# stationary
# getting stationarity of ticker SSL
# getting stationarity of ticker SST
# stationary
# getting stationarity of ticker SSTK
# getting stationarity of ticker ST
# getting stationarity of ticker STAG
# getting stationarity of ticker STEL
# stationary
# getting stationarity of ticker STEM
# getting stationarity of ticker STEW
# stationary
# getting stationarity of ticker STG
# stationary
# getting stationarity of ticker STK
# getting stationarity of ticker STLA
# stationary
# getting stationarity of ticker STM
# stationary
# getting stationarity of ticker STNG
# stationary
# getting stationarity of ticker STR
# stationary
# getting stationarity of ticker STRV
# getting stationarity of ticker STVN
# getting stationarity of ticker STWD
# stationary
# getting stationarity of ticker STXD
# stationary
# getting stationarity of ticker STXE
# stationary
# getting stationarity of ticker STXG
# getting stationarity of ticker STXI
# stationary
# getting stationarity of ticker STXK
# getting stationarity of ticker STXM
# getting stationarity of ticker STXT
# getting stationarity of ticker STXV
# getting stationarity of ticker SU
# stationary
# getting stationarity of ticker SUM
# getting stationarity of ticker SUN
# getting stationarity of ticker SUP
# getting stationarity of ticker SUPP
# stationary
# getting stationarity of ticker SUPV
# getting stationarity of ticker SUZ
# getting stationarity of ticker SVV
# getting stationarity of ticker SW
# getting stationarity of ticker SWI
# getting stationarity of ticker SWN
# getting stationarity of ticker SWX
# getting stationarity of ticker SWZ
# getting stationarity of ticker SXC
# getting stationarity of ticker SYF
# getting stationarity of ticker T
# getting stationarity of ticker TAC
# getting stationarity of ticker TAK
# getting stationarity of ticker TAL
# getting stationarity of ticker TALO
# getting stationarity of ticker TAP
# stationary
# getting stationarity of ticker TBB
# stationary
# getting stationarity of ticker TBBB
# getting stationarity of ticker TBC
# getting stationarity of ticker TBI
# getting stationarity of ticker TBN
# getting stationarity of ticker TCI
# stationary
# getting stationarity of ticker TCS
# stationary
# getting stationarity of ticker TD
# getting stationarity of ticker TDC
# getting stationarity of ticker TDF
# getting stationarity of ticker TDOC
# getting stationarity of ticker TDS
# stationary
# getting stationarity of ticker TDW
# getting stationarity of ticker TEAF
# stationary
# getting stationarity of ticker TECK
# stationary
# getting stationarity of ticker TEF
# getting stationarity of ticker TEI
# stationary
# getting stationarity of ticker TEN
# getting stationarity of ticker TEO
# stationary
# getting stationarity of ticker TEVA
# getting stationarity of ticker TEX
# getting stationarity of ticker TFC
# getting stationarity of ticker TFPM
# getting stationarity of ticker TFSA
# stationary
# getting stationarity of ticker TG
# stationary
# getting stationarity of ticker TGI
# getting stationarity of ticker TGLS
# getting stationarity of ticker TGNA
# getting stationarity of ticker TGS
# getting stationarity of ticker THLV
# stationary
# getting stationarity of ticker THQ
# stationary
# getting stationarity of ticker THR
# stationary
# getting stationarity of ticker THS
# stationary
# getting stationarity of ticker THW
# getting stationarity of ticker TIMB
# getting stationarity of ticker TISI
# getting stationarity of ticker TIXT
# getting stationarity of ticker TK
# getting stationarity of ticker TKC
# stationary
# getting stationarity of ticker TLK
# stationary
# getting stationarity of ticker TLYS
# stationary
# getting stationarity of ticker TME
# getting stationarity of ticker TMHC
# getting stationarity of ticker TNK
# getting stationarity of ticker TNL
# stationary
# getting stationarity of ticker TOST
# getting stationarity of ticker TPB
# getting stationarity of ticker TPC
# getting stationarity of ticker TPH
# getting stationarity of ticker TPR
# getting stationarity of ticker TPTA
# getting stationarity of ticker TPVG
# getting stationarity of ticker TPX
# stationary
# getting stationarity of ticker TPZ
# getting stationarity of ticker TR
# getting stationarity of ticker TRAK
# stationary
# getting stationarity of ticker TRC
# getting stationarity of ticker TREX
# getting stationarity of ticker TRN
# stationary
# getting stationarity of ticker TRNO
# stationary
# getting stationarity of ticker TROX
# getting stationarity of ticker TRP
# stationary
# getting stationarity of ticker TRTX
# stationary
# getting stationarity of ticker TS
# getting stationarity of ticker TSE
# getting stationarity of ticker TSI
# getting stationarity of ticker TSLX
# getting stationarity of ticker TSN
# getting stationarity of ticker TSQ
# getting stationarity of ticker TTE
# stationary
# getting stationarity of ticker TTI
# getting stationarity of ticker TTP
# getting stationarity of ticker TU
# getting stationarity of ticker TUP
# getting stationarity of ticker TUYA
# stationary
# getting stationarity of ticker TV
# stationary
# getting stationarity of ticker TVC
# stationary
# getting stationarity of ticker TVE
# stationary
# getting stationarity of ticker TWI
# getting stationarity of ticker TWLO
# getting stationarity of ticker TWN
# stationary
# getting stationarity of ticker TWO
# stationary
# getting stationarity of ticker TX
# getting stationarity of ticker TXNM
# getting stationarity of ticker TXO
# stationary
# getting stationarity of ticker TY
# getting stationarity of ticker TYG
# getting stationarity of ticker U
# getting stationarity of ticker UA
# getting stationarity of ticker UAA
# getting stationarity of ticker UAN
# getting stationarity of ticker UBER
# getting stationarity of ticker UBS
# getting stationarity of ticker UCB
# stationary
# getting stationarity of ticker UDR
# stationary
# getting stationarity of ticker UE
# getting stationarity of ticker UFI
# getting stationarity of ticker UGI
# getting stationarity of ticker UGP
# getting stationarity of ticker UHAL
# stationary
# getting stationarity of ticker UHT
# stationary
# getting stationarity of ticker UIS
# stationary
# getting stationarity of ticker UL
# getting stationarity of ticker ULS
# getting stationarity of ticker UMC
# stationary
# getting stationarity of ticker UMH
# getting stationarity of ticker UNFI
# getting stationarity of ticker UNM
# getting stationarity of ticker UNMA
# getting stationarity of ticker UP
# stationary
# getting stationarity of ticker USA
# getting stationarity of ticker USAC
# stationary
# getting stationarity of ticker USB
# getting stationarity of ticker USFD
# getting stationarity of ticker USM
# stationary
# getting stationarity of ticker USNA
# getting stationarity of ticker UTF
# stationary
# getting stationarity of ticker UTI
# stationary
# getting stationarity of ticker UTL
# getting stationarity of ticker UTZ
# getting stationarity of ticker UVE
# stationary
# getting stationarity of ticker UVV
# getting stationarity of ticker UWMC
# getting stationarity of ticker UZD
# stationary
# getting stationarity of ticker UZE
# stationary
# getting stationarity of ticker UZF
# getting stationarity of ticker VAC
# stationary
# getting stationarity of ticker VAL
# getting stationarity of ticker VALE
# getting stationarity of ticker VATE
# stationary
# getting stationarity of ticker VBF
# stationary
# getting stationarity of ticker VCV
# stationary
# getting stationarity of ticker VEL
# getting stationarity of ticker VET
# getting stationarity of ticker VFC
# stationary
# getting stationarity of ticker VGI
# getting stationarity of ticker VGM
# getting stationarity of ticker VGR
# getting stationarity of ticker VHC
# stationary
# getting stationarity of ticker VHI
# stationary
# getting stationarity of ticker VICI
# getting stationarity of ticker VIK
# getting stationarity of ticker VIPS
# getting stationarity of ticker VIST
# stationary
# getting stationarity of ticker VIV
# getting stationarity of ticker VKQ
# getting stationarity of ticker VLN
# getting stationarity of ticker VLRS
# getting stationarity of ticker VLT
# stationary
# getting stationarity of ticker VMO
# getting stationarity of ticker VNCE
# stationary
# getting stationarity of ticker VNO
# stationary
# getting stationarity of ticker VNT
# getting stationarity of ticker VOC
# getting stationarity of ticker VOTE
# getting stationarity of ticker VPG
# getting stationarity of ticker VPV
# getting stationarity of ticker VRE
# getting stationarity of ticker VRN
# getting stationarity of ticker VSCO
# getting stationarity of ticker VSH
# getting stationarity of ticker VSTO
# stationary
# getting stationarity of ticker VSTS
# getting stationarity of ticker VTEX
# getting stationarity of ticker VTLE
# getting stationarity of ticker VTMX
# getting stationarity of ticker VTN
# stationary
# getting stationarity of ticker VTOL
# stationary
# getting stationarity of ticker VTR
# getting stationarity of ticker VTS
# getting stationarity of ticker VVI
# getting stationarity of ticker VVR
# getting stationarity of ticker VVV
# getting stationarity of ticker VVX
# getting stationarity of ticker VYX
# stationary
# getting stationarity of ticker VZ
# getting stationarity of ticker VZIO
# getting stationarity of ticker W
# getting stationarity of ticker WBS
# stationary
# getting stationarity of ticker WBX
# getting stationarity of ticker WDH
# getting stationarity of ticker WDI
# stationary
# getting stationarity of ticker WDS
# getting stationarity of ticker WEA
# getting stationarity of ticker WEAV
# stationary
# getting stationarity of ticker WEL
# getting stationarity of ticker WES
# stationary
# getting stationarity of ticker WF
# getting stationarity of ticker WFC
# stationary
# getting stationarity of ticker WGO
# stationary
# getting stationarity of ticker WHD
# stationary
# getting stationarity of ticker WHG
# stationary
# getting stationarity of ticker WIA
# getting stationarity of ticker WINN
# getting stationarity of ticker WIT
# stationary
# getting stationarity of ticker WIW
# stationary
# getting stationarity of ticker WK
# stationary
# getting stationarity of ticker WKC
# getting stationarity of ticker WLKP
# getting stationarity of ticker WLTG
# getting stationarity of ticker WLY
# stationary
# getting stationarity of ticker WLYB
# stationary
# getting stationarity of ticker WMB
# stationary
# getting stationarity of ticker WMK
# getting stationarity of ticker WNC
# getting stationarity of ticker WNS
# getting stationarity of ticker WOLF
# getting stationarity of ticker WOR
# stationary
# getting stationarity of ticker WOW
# getting stationarity of ticker WPC
# getting stationarity of ticker WPM
# stationary
# getting stationarity of ticker WPP
# getting stationarity of ticker WRB
# getting stationarity of ticker WRBY
# stationary
# getting stationarity of ticker WS
# stationary
# getting stationarity of ticker WSR
# getting stationarity of ticker WT
# stationary
# getting stationarity of ticker WTI
# getting stationarity of ticker WTRG
# stationary
# getting stationarity of ticker WTTR
# getting stationarity of ticker WU
# getting stationarity of ticker WWW
# getting stationarity of ticker WY
# getting stationarity of ticker X
# getting stationarity of ticker XFLT
# getting stationarity of ticker XHR
# getting stationarity of ticker XIN
# stationary
# getting stationarity of ticker XPER
# getting stationarity of ticker XPEV
# stationary
# getting stationarity of ticker XPOF
# getting stationarity of ticker XPRO
# stationary
# getting stationarity of ticker XYF
# stationary
# getting stationarity of ticker YALA
# getting stationarity of ticker YELP
# stationary
# getting stationarity of ticker YETI
# getting stationarity of ticker YEXT
# getting stationarity of ticker YMM
# getting stationarity of ticker YOU
# stationary
# getting stationarity of ticker YPF
# getting stationarity of ticker YRD
# getting stationarity of ticker YSG
# getting stationarity of ticker YUMC
# stationary
# getting stationarity of ticker ZEPP
# stationary
# getting stationarity of ticker ZETA
# getting stationarity of ticker ZGN
# stationary
# getting stationarity of ticker ZH
# getting stationarity of ticker ZIM
# getting stationarity of ticker ZIP
# getting stationarity of ticker ZK
# getting stationarity of ticker ZKH
# getting stationarity of ticker ZTO
# getting stationarity of ticker ZTR
# stationary
# getting stationarity of ticker ZUO
# getting stationarity of ticker ZVIA
# stationary
# getting stationarity of ticker ZWS
# stationary

# %% [markdown]
# now we have a list of tickers filtered by price and stationarity of log returns between 30 days ago and now

# %%
print(len(stationary_tickers))
# Out:
# 628

# %% [markdown]
# filter by volume >= 200k and volatility >= 10%

# %%
filtered_tickers = []
for i, ticker in enumerate(stationary_tickers):
    price_data = data.ohlcv(ticker, datetime.date.today() - datetime.timedelta(days=lookback), datetime.date.today())
    avg_volume = np.mean(price_data['Volume'])
    volatility = np.std(price_data['Close'])
    if avg_volume > 200000 and volatility > 0.1: filtered_tickers.append(ticker)
# Out:
# 1 Failed download:
# - DXYZ: No data found for this date range, symbol may be delisted

# %%
print(len(filtered_tickers))
data.write_to_txt_file(filtered_tickers, 'low_cap_stationary_tickers_' + str(datetime.date.today()))
# Out:
# 320
# wrote tickers to file low_cap_stationary_tickers_2024-09-14

# %%
print(data.get_risk_free_rate())
# Out:
# 0.03620999813079834
